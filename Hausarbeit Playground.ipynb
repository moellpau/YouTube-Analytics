# %% [markdown]
# **Exploratory Data Analysing Using Youtube Video Data from Most YouTube Influencers in Germany**

# %% [markdown]
# Quelle für den Scraper Programmcode von https://github.com/thu-vu92/youtube-api-analysis, abgerufen am: 02.11.2022

# %%
from googleapiclient.discovery import build
import pandas as pd
from distutils import errors
from pathlib import Path

# %%
#remove before upload to GitHub
api_key = 'AIzaSyBJ7mfYocgj8mEx3Ts41FmLGVHcSNbTd6s' #Paula's Key

channel_ids = ["UCYJ61XIK64sp6ZFFS8sctxw", #Gronkh
               "UCTXeJ33DzXI2veQpKfrvaYw", #Julien Bam
               "UCcn4UOBvB0W2HjCcLFLuu2w", #ungespielt
               "UCLCb_YDL9XfSYsWpS5xrO5Q", #Rezo
               "UCpAMOlA_0hFXopIxMq8ar0w", #MontanaBlack
               "UCpZ_DI-ZugwMzXcqccaTVsg", #Dagi Bee
               "UCHfdTAyg5t4mb1G-3rJ6QsQ", #BibisBeautyPalace 
               "UCdFWqYbJHMZGbOs0efRwmsg", #xLL by Lisa & Lena
               "UChVRfsT_ASBZk10o0An7Ucg", #Pamela Reif
               "UCi3OE-aN09WOcN9d2stCvPg" ] #charli d'amelio

api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):
    
    """
    Get channel stats
    
    Params:
    ------
    youtube: build object of Youtube API
    channel_ids: list of channel IDs
    
    Returns:
    ------
    dataframe with all channel stats for each channel ID
    
    """
    
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    # loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
        all_data.append(data)
        
    return(pd.DataFrame(all_data))

def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId=playlist_id,
        maxResults = 50
    )
    response = request.execute()
 
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    while next_page_token is not None:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId = playlist_id,
                    maxResults = 50,
                    pageToken = next_page_token)
        response = request.execute()

        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        next_page_token = response.get('nextPageToken')
        
    return video_ids

def get_video_details(youtube, video_ids):

    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics,topicDetails",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption'],
                             'topicDetails': ['topicCategories']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    
    return pd.DataFrame(all_video_info)


def get_comments_in_videos(youtube, video_ids):
    """
    Get top level comments as text from all videos with given IDs (only the first 10 comments due to quote limit of Youtube API)
    Params:
    
    youtube: the build object from googleapiclient.discovery
    video_ids: list of video IDs
    
    Returns:
    Dataframe with video IDs and associated top level comment in text.
    
    """

    all_comments = []
    print('Got '+str(len(video_ids)) + ' video IDs ')
    percent = 0.0
    
    for video_id in video_ids:
        #next_page_token = response.get('nextPageToken')
        #while next_page_token is not None:
            try:   
                request = youtube.commentThreads().list(
                    part="snippet,replies",
                    videoId=video_id,
                    maxResults=100,
                    textFormat="plainText"
                    #pageToken = next_page_token
                )
                response = request.execute()
            
                comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items']]
                comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}

                #next_page_token = response.get('nextPageToken')
                
            except: 
                # When error occurs - most likely because comments are disabled on a video
                print('Could not get comments for video ' + video_id)


        
    return pd.DataFrame(all_comments)

# %%
def get_comment_threads(youtube, video_id):
    try:
        results = youtube.commentThreads().list(
            part="snippet",
            maxResults=150,
            videoId=video_id
        ).execute()

        return results
    except:
        # When error occurs - most likely because comments are disabled on a video
        print('Could not get comments for video ' + video_id)
        return None

# %%
def load_comments(result):
    comments = []

    for item in result["items"]:
        comment = item["snippet"]["topLevelComment"]
        author = comment["snippet"]["authorDisplayName"]
        text = comment["snippet"]["textDisplay"]
        # print("Comment by {}: {}".format(author, text))
        
        comments.append(text)
    
    return comments

# %%
channel_data = get_channel_stats(youtube, channel_ids)

# %%
channel_data
# Out:
#           channelName subscribers       views totalVideos  \
# 0            Dagi Bee     3960000  1061882356         644
# 1     charli d'amelio     9470000   305646938          64
# 2   BibisBeautyPalace     5880000  2875928915         956
# 3          ungespielt     3760000  2118366292        4768
# 4                rezo     1750000   191478344          49
# 5        MontanaBlack     2910000   323532581         371
# 6  xLL by Lisa & Lena      887000    58660820          53
# 7              Gronkh     4920000  3653270484       15124
# 8         Pamela Reif     9230000  1581102771         186
# 9          Julien Bam     6000000  1588456718         238
#
#                  playlistId
# 0  UUpZ_DI-ZugwMzXcqccaTVsg
# 1  UUi3OE-aN09WOcN9d2stCvPg
# 2  UUHfdTAyg5t4mb1G-3rJ6QsQ
# 3  UUcn4UOBvB0W2HjCcLFLuu2w
# 4  UULCb_YDL9XfSYsWpS5xrO5Q
# 5  UUpAMOlA_0hFXopIxMq8ar0w
# 6  UUdFWqYbJHMZGbOs0efRwmsg
# 7  UUYJ61XIK64sp6ZFFS8sctxw
# 8  UUhVRfsT_ASBZk10o0An7Ucg
# 9  UUTXeJ33DzXI2veQpKfrvaYw

# %%
# Create a dataframe with video statistics from all channels

video_df = pd.DataFrame()

for c in channel_data['channelName'].unique():
    print("Getting video information from channel: " + c)
    playlist_id = channel_data.loc[channel_data['channelName']== c, 'playlistId'].iloc[0]
    video_ids = get_video_ids(youtube, playlist_id)
    
    # get video data
    video_data = get_video_details(youtube, video_ids)

    # append video data together and comment data toghether
    video_df = video_df.append(video_data, ignore_index=True)
# Out:
# Getting video information from channel: Dagi Bee
# C:\Users\D074066\AppData\Local\Temp\ipykernel_19920\1963951395.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# Getting video information from channel: charli d'amelio
# C:\Users\D074066\AppData\Local\Temp\ipykernel_19920\1963951395.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# Getting video information from channel: BibisBeautyPalace
# C:\Users\D074066\AppData\Local\Temp\ipykernel_19920\1963951395.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# Getting video information from channel: ungespielt
# C:\Users\D074066\AppData\Local\Temp\ipykernel_19920\1963951395.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# Getting video information from channel: rezo
# C:\Users\D074066\AppData\Local\Temp\ipykernel_19920\1963951395.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# Getting video information from channel: MontanaBlack
# C:\Users\D074066\AppData\Local\Temp\ipykernel_19920\1963951395.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# Getting video information from channel: xLL by Lisa & Lena
# C:\Users\D074066\AppData\Local\Temp\ipykernel_19920\1963951395.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# Getting video information from channel: Gronkh
# C:\Users\D074066\AppData\Local\Temp\ipykernel_19920\1963951395.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# Getting video information from channel: Pamela Reif
# C:\Users\D074066\AppData\Local\Temp\ipykernel_19920\1963951395.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)
# Getting video information from channel: Julien Bam
# C:\Users\D074066\AppData\Local\Temp\ipykernel_19920\1963951395.py:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   video_df = video_df.append(video_data, ignore_index=True)

# %%
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)

# %%
video_data = video_df[0:0]

channel_title = video_df['channelTitle'].unique()[0]

# get videos for selected channel
temp = video_df.loc[video_df['channelTitle'] == channel_title]
# sort data by video view count
temp.sort_values('viewCount', ascending=False)
# only get top 30 videos
temp = temp.head(30)
temp.reset_index(inplace=True)
temp.apply(pd.to_numeric, errors = 'coerce', axis = 1)
# temp.drop(temp.columns[[0]], axis=1, inplace=True)

# append found videos to video_data dataframe
video_data = pd.concat([temp,video_data],  ignore_index=False)
# video_data.append(temp)

comments_query = get_comment_threads(youtube=youtube, video_id=temp['video_id'].to_list()[0])
comments = load_comments(result=comments_query)

# %%
# 22-11-19 : read comments by artist and video
from timeit import default_timer as timer

video_data = video_df[0:0]


for channel_title in video_df['channelTitle'].unique():
    print("== QUERYING DATA FOR CHANNEL ["+channel_title+"]")
    channel_comment_data = []
    
    # get videos for selected channel
    temp = video_df.loc[video_df['channelTitle'] == channel_title]
    # sort data by video view count
    temp.sort_values('viewCount', ascending=False)
    # only get top 30 videos
    temp = temp.head(30)
    temp.reset_index(inplace=True)
    temp.apply(pd.to_numeric, errors = 'coerce', axis = 1)
    # temp.drop(temp.columns[[0]], axis=1, inplace=True)

    # append found videos to video_data dataframe
    video_data = pd.concat([temp,video_data],  ignore_index=False)
    # video_data.append(temp)

    print(" - got video data for " + channel_title + "with " + str(len(video_data.index)) +" videos")

    # get 100 comments for each of the 30 retrieved videos
    for video in temp['video_id']:
        print(" - retrieving comment data for ID="+video +" [" + channel_title + "]")
        _start = timer()

        # video id for current video
        current_video_id = video
        # query comments for that video
        comments_query = get_comment_threads(youtube=youtube, video_id=current_video_id)

        if comments_query is None:
            comments = []
            print("got no comments")
        else:
            # retrieve queried comments as list of strings
            comments = load_comments(result=comments_query)

        _end = timer()

        print(" - queried "+ str(len(comments)) +" comments (took " + str(round((_end - _start),4)) + "s) from ID="+video +" [" + channel_title + "]")

        # append to all comment data we have so far from channel
        # for com in comments:
        #     channel_comment_data.append(com)
        # were appending a list of comments as strings to our total list of comments for this particular youtube star
        channel_comment_data += comments

    # we're done with comments for this channel
    # lets save them locally as csv
    csv_data = pd.Series(channel_comment_data)
    print(" - saving " + str(len(csv_data.index)) + "comments from creator [" + channel_title + "] to local harddrive")
    # save channel comments as csv file
    csv_data.to_csv('C:/Users/D074066/Downloads/'+channel_title+'_comments.csv', sep=';',encoding='utf-16')
    print(" - ... SAVED CSV SUCCESSFULLY")

video_data.to_csv('C:/Users/D074066/Downloads/'+'videos_top30.csv', sep=';')
# Out:
# == QUERYING DATA FOR CHANNEL [Dagi Bee]
#  - got video data for Dagi Beewith 30 videos
#  - retrieving comment data for ID=TfIY6KLnJgg [Dagi Bee]
#  - queried 100 comments (took 0.6669s) from ID=TfIY6KLnJgg [Dagi Bee]
#  - retrieving comment data for ID=3w-EyQ6P0sU [Dagi Bee]
#  - queried 85 comments (took 0.2198s) from ID=3w-EyQ6P0sU [Dagi Bee]
#  - retrieving comment data for ID=JBavdh_I3DQ [Dagi Bee]
#  - queried 100 comments (took 0.2611s) from ID=JBavdh_I3DQ [Dagi Bee]
#  - retrieving comment data for ID=DKAQorfKg_E [Dagi Bee]
#  - queried 100 comments (took 0.2144s) from ID=DKAQorfKg_E [Dagi Bee]
#  - retrieving comment data for ID=4WC1KE5vfuA [Dagi Bee]
#  - queried 100 comments (took 0.2176s) from ID=4WC1KE5vfuA [Dagi Bee]
#  - retrieving comment data for ID=iYJlDKPaQMk [Dagi Bee]
#  - queried 100 comments (took 0.2296s) from ID=iYJlDKPaQMk [Dagi Bee]
#  - retrieving comment data for ID=h3zYPkxHeX4 [Dagi Bee]
#  - queried 100 comments (took 0.3898s) from ID=h3zYPkxHeX4 [Dagi Bee]
#  - retrieving comment data for ID=sACBGH7-SgM [Dagi Bee]
#  - queried 100 comments (took 0.2319s) from ID=sACBGH7-SgM [Dagi Bee]
#  - retrieving comment data for ID=Rot2f5QTQls [Dagi Bee]
#  - queried 100 comments (took 0.2001s) from ID=Rot2f5QTQls [Dagi Bee]
#  - retrieving comment data for ID=vHxwQ-rlwkM [Dagi Bee]
#  - queried 100 comments (took 0.214s) from ID=vHxwQ-rlwkM [Dagi Bee]
#  - retrieving comment data for ID=7ngXXbROZME [Dagi Bee]
#  - queried 100 comments (took 0.2126s) from ID=7ngXXbROZME [Dagi Bee]
#  - retrieving comment data for ID=SPAtaut9WJs [Dagi Bee]
#  - queried 100 comments (took 0.2181s) from ID=SPAtaut9WJs [Dagi Bee]
#  - retrieving comment data for ID=uB1lTvVNuQI [Dagi Bee]
#  - queried 100 comments (took 0.4406s) from ID=uB1lTvVNuQI [Dagi Bee]
#  - retrieving comment data for ID=x0gUmNpuPOw [Dagi Bee]
#  - queried 100 comments (took 0.2005s) from ID=x0gUmNpuPOw [Dagi Bee]
#  - retrieving comment data for ID=8-LTPLsaejQ [Dagi Bee]
#  - queried 100 comments (took 0.2394s) from ID=8-LTPLsaejQ [Dagi Bee]
#  - retrieving comment data for ID=1tRQF_thZxo [Dagi Bee]
#  - queried 100 comments (took 0.2309s) from ID=1tRQF_thZxo [Dagi Bee]
#  - retrieving comment data for ID=10Xano3bfxw [Dagi Bee]
#  - queried 100 comments (took 0.1911s) from ID=10Xano3bfxw [Dagi Bee]
#  - retrieving comment data for ID=hYAlDUheKa0 [Dagi Bee]
#  - queried 100 comments (took 0.2172s) from ID=hYAlDUheKa0 [Dagi Bee]
#  - retrieving comment data for ID=EswrGUqGVZE [Dagi Bee]
#  - queried 100 comments (took 0.1813s) from ID=EswrGUqGVZE [Dagi Bee]
#  - retrieving comment data for ID=o6TTUoq-rjU [Dagi Bee]
#  - queried 100 comments (took 0.1932s) from ID=o6TTUoq-rjU [Dagi Bee]
#  - retrieving comment data for ID=JM7MgHt-K0k [Dagi Bee]
#  - queried 100 comments (took 0.1921s) from ID=JM7MgHt-K0k [Dagi Bee]
#  - retrieving comment data for ID=A93i4d07RgY [Dagi Bee]
#  - queried 100 comments (took 0.2167s) from ID=A93i4d07RgY [Dagi Bee]
#  - retrieving comment data for ID=nEt_YEK1hqI [Dagi Bee]
#  - queried 100 comments (took 0.2201s) from ID=nEt_YEK1hqI [Dagi Bee]
#  - retrieving comment data for ID=RQP-XZEgXwA [Dagi Bee]
#  - queried 100 comments (took 0.2001s) from ID=RQP-XZEgXwA [Dagi Bee]
#  - retrieving comment data for ID=oz7y3PHyryA [Dagi Bee]
#  - queried 100 comments (took 0.1998s) from ID=oz7y3PHyryA [Dagi Bee]
#  - retrieving comment data for ID=IvfjqlBWcWU [Dagi Bee]
#  - queried 100 comments (took 0.4552s) from ID=IvfjqlBWcWU [Dagi Bee]
#  - retrieving comment data for ID=Y-wIYaHfhWU [Dagi Bee]
#  - queried 100 comments (took 0.1942s) from ID=Y-wIYaHfhWU [Dagi Bee]
#  - retrieving comment data for ID=jeeDgIadozM [Dagi Bee]
#  - queried 100 comments (took 0.2086s) from ID=jeeDgIadozM [Dagi Bee]
#  - retrieving comment data for ID=qWGX9VQFjqY [Dagi Bee]
#  - queried 100 comments (took 0.1908s) from ID=qWGX9VQFjqY [Dagi Bee]
#  - retrieving comment data for ID=h_yzFmsm5u8 [Dagi Bee]
#  - queried 100 comments (took 0.2122s) from ID=h_yzFmsm5u8 [Dagi Bee]
#  - saving 2985comments from creator [Dagi Bee] to local harddrive
#  - ... SAVED CSV SUCCESSFULLY
# == QUERYING DATA FOR CHANNEL [charli d'amelio]
#  - got video data for charli d'ameliowith 60 videos
#  - retrieving comment data for ID=5My2SVDYQL4 [charli d'amelio]
#  - queried 99 comments (took 0.2044s) from ID=5My2SVDYQL4 [charli d'amelio]
#  - retrieving comment data for ID=JP3f2FJtbwI [charli d'amelio]
#  - queried 98 comments (took 0.2045s) from ID=JP3f2FJtbwI [charli d'amelio]
#  - retrieving comment data for ID=xVf75rW9Fa4 [charli d'amelio]
#  - queried 100 comments (took 0.1941s) from ID=xVf75rW9Fa4 [charli d'amelio]
#  - retrieving comment data for ID=cePNNb3rg_4 [charli d'amelio]
#  - queried 97 comments (took 0.3321s) from ID=cePNNb3rg_4 [charli d'amelio]
#  - retrieving comment data for ID=9ZnhZcHEL88 [charli d'amelio]
#  - queried 100 comments (took 0.2591s) from ID=9ZnhZcHEL88 [charli d'amelio]
#  - retrieving comment data for ID=u9YtGLY6UUE [charli d'amelio]
#  - queried 100 comments (took 0.4388s) from ID=u9YtGLY6UUE [charli d'amelio]
#  - retrieving comment data for ID=QFfGC7IItJo [charli d'amelio]
#  - queried 100 comments (took 0.1923s) from ID=QFfGC7IItJo [charli d'amelio]
#  - retrieving comment data for ID=Oo9nLGzw5hQ [charli d'amelio]
#  - queried 100 comments (took 0.2078s) from ID=Oo9nLGzw5hQ [charli d'amelio]
#  - retrieving comment data for ID=QBix-PKv08U [charli d'amelio]
#  - queried 100 comments (took 0.1877s) from ID=QBix-PKv08U [charli d'amelio]
#  - retrieving comment data for ID=1OzUV_GA_qM [charli d'amelio]
# Could not get comments for video 1OzUV_GA_qM
# got no comments
#  - queried 0 comments (took 0.1016s) from ID=1OzUV_GA_qM [charli d'amelio]
#  - retrieving comment data for ID=_SKVFtLtJws [charli d'amelio]
#  - queried 100 comments (took 0.9508s) from ID=_SKVFtLtJws [charli d'amelio]
#  - retrieving comment data for ID=-D4ErBWFwO4 [charli d'amelio]
#  - queried 100 comments (took 0.2427s) from ID=-D4ErBWFwO4 [charli d'amelio]
#  - retrieving comment data for ID=793Ib70BWlM [charli d'amelio]
#  - queried 100 comments (took 0.2166s) from ID=793Ib70BWlM [charli d'amelio]
#  - retrieving comment data for ID=bS3uUY3cV-k [charli d'amelio]
#  - queried 100 comments (took 0.4159s) from ID=bS3uUY3cV-k [charli d'amelio]
#  - retrieving comment data for ID=uq9prnTO-2U [charli d'amelio]
#  - queried 100 comments (took 0.3219s) from ID=uq9prnTO-2U [charli d'amelio]
#  - retrieving comment data for ID=5OYFwMNgvzc [charli d'amelio]
#  - queried 100 comments (took 0.2004s) from ID=5OYFwMNgvzc [charli d'amelio]
#  - retrieving comment data for ID=TlefVuHFHqM [charli d'amelio]
#  - queried 100 comments (took 0.2168s) from ID=TlefVuHFHqM [charli d'amelio]
#  - retrieving comment data for ID=adb1fjA45SI [charli d'amelio]
#  - queried 100 comments (took 0.3762s) from ID=adb1fjA45SI [charli d'amelio]
#  - retrieving comment data for ID=xesyaJ0vgbY [charli d'amelio]
#  - queried 100 comments (took 0.2239s) from ID=xesyaJ0vgbY [charli d'amelio]
#  - retrieving comment data for ID=awygkEn9gEY [charli d'amelio]
#  - queried 100 comments (took 0.2115s) from ID=awygkEn9gEY [charli d'amelio]
#  - retrieving comment data for ID=WryC2STldag [charli d'amelio]
#  - queried 100 comments (took 0.1969s) from ID=WryC2STldag [charli d'amelio]
#  - retrieving comment data for ID=HEK67PAH5iM [charli d'amelio]
#  - queried 100 comments (took 0.2019s) from ID=HEK67PAH5iM [charli d'amelio]
#  - retrieving comment data for ID=zaCkYUCrjOk [charli d'amelio]
#  - queried 100 comments (took 0.1911s) from ID=zaCkYUCrjOk [charli d'amelio]
#  - retrieving comment data for ID=ZNIwjuIvw-Q [charli d'amelio]
#  - queried 100 comments (took 0.1831s) from ID=ZNIwjuIvw-Q [charli d'amelio]
#  - retrieving comment data for ID=NXZo0xJk2WQ [charli d'amelio]
#  - queried 100 comments (took 0.399s) from ID=NXZo0xJk2WQ [charli d'amelio]
#  - retrieving comment data for ID=2ru9lHy65TE [charli d'amelio]
#  - queried 100 comments (took 0.3997s) from ID=2ru9lHy65TE [charli d'amelio]
#  - retrieving comment data for ID=u-fQJ7PWkaA [charli d'amelio]
#  - queried 100 comments (took 0.1812s) from ID=u-fQJ7PWkaA [charli d'amelio]
#  - retrieving comment data for ID=7HYXPp_-c3A [charli d'amelio]
#  - queried 100 comments (took 0.4311s) from ID=7HYXPp_-c3A [charli d'amelio]
#  - retrieving comment data for ID=ggyV9qgP2IE [charli d'amelio]
#  - queried 100 comments (took 0.3025s) from ID=ggyV9qgP2IE [charli d'amelio]
#  - retrieving comment data for ID=oyLmRSydsUg [charli d'amelio]
#  - queried 100 comments (took 0.1751s) from ID=oyLmRSydsUg [charli d'amelio]
#  - saving 2894comments from creator [charli d'amelio] to local harddrive
#  - ... SAVED CSV SUCCESSFULLY
# == QUERYING DATA FOR CHANNEL [BibisBeautyPalace]
#  - got video data for BibisBeautyPalacewith 90 videos
#  - retrieving comment data for ID=6KBqc9TOcGM [BibisBeautyPalace]
#  - queried 100 comments (took 0.2521s) from ID=6KBqc9TOcGM [BibisBeautyPalace]
#  - retrieving comment data for ID=stEkNwYvL_c [BibisBeautyPalace]
#  - queried 100 comments (took 0.2116s) from ID=stEkNwYvL_c [BibisBeautyPalace]
#  - retrieving comment data for ID=KrfrZCnVJ2I [BibisBeautyPalace]
#  - queried 100 comments (took 0.2092s) from ID=KrfrZCnVJ2I [BibisBeautyPalace]
#  - retrieving comment data for ID=75Q-K7PQLk8 [BibisBeautyPalace]
#  - queried 100 comments (took 0.2077s) from ID=75Q-K7PQLk8 [BibisBeautyPalace]
#  - retrieving comment data for ID=TVOBglDMAHI [BibisBeautyPalace]
#  - queried 100 comments (took 0.479s) from ID=TVOBglDMAHI [BibisBeautyPalace]
#  - retrieving comment data for ID=GGDOpj33Z4k [BibisBeautyPalace]
#  - queried 100 comments (took 0.2093s) from ID=GGDOpj33Z4k [BibisBeautyPalace]
#  - retrieving comment data for ID=MYyJOyyNtic [BibisBeautyPalace]
#  - queried 100 comments (took 0.1988s) from ID=MYyJOyyNtic [BibisBeautyPalace]
#  - retrieving comment data for ID=YkXxRMGtXIY [BibisBeautyPalace]
#  - queried 100 comments (took 0.2049s) from ID=YkXxRMGtXIY [BibisBeautyPalace]
#  - retrieving comment data for ID=8ZIMdd7yAlc [BibisBeautyPalace]
#  - queried 100 comments (took 0.5549s) from ID=8ZIMdd7yAlc [BibisBeautyPalace]
#  - retrieving comment data for ID=FlFIMhJf0C8 [BibisBeautyPalace]
#  - queried 100 comments (took 0.3384s) from ID=FlFIMhJf0C8 [BibisBeautyPalace]
#  - retrieving comment data for ID=oYr0ngl9NQk [BibisBeautyPalace]
#  - queried 100 comments (took 0.3125s) from ID=oYr0ngl9NQk [BibisBeautyPalace]
#  - retrieving comment data for ID=j3oEKG4wCHE [BibisBeautyPalace]
#  - queried 100 comments (took 0.2333s) from ID=j3oEKG4wCHE [BibisBeautyPalace]
#  - retrieving comment data for ID=PMl-eg4hqFk [BibisBeautyPalace]
#  - queried 100 comments (took 0.1899s) from ID=PMl-eg4hqFk [BibisBeautyPalace]
#  - retrieving comment data for ID=L_NY-I1R2Os [BibisBeautyPalace]
#  - queried 100 comments (took 0.1922s) from ID=L_NY-I1R2Os [BibisBeautyPalace]
#  - retrieving comment data for ID=884E62kZFeQ [BibisBeautyPalace]
#  - queried 100 comments (took 0.2356s) from ID=884E62kZFeQ [BibisBeautyPalace]
#  - retrieving comment data for ID=TAuuIgsxu5Y [BibisBeautyPalace]
#  - queried 100 comments (took 0.187s) from ID=TAuuIgsxu5Y [BibisBeautyPalace]
#  - retrieving comment data for ID=PfVQRXEccjE [BibisBeautyPalace]
#  - queried 100 comments (took 0.3819s) from ID=PfVQRXEccjE [BibisBeautyPalace]
#  - retrieving comment data for ID=xMJ2FP4rFKc [BibisBeautyPalace]
#  - queried 100 comments (took 0.2008s) from ID=xMJ2FP4rFKc [BibisBeautyPalace]
#  - retrieving comment data for ID=SFtybDO37Eo [BibisBeautyPalace]
#  - queried 100 comments (took 0.1993s) from ID=SFtybDO37Eo [BibisBeautyPalace]
#  - retrieving comment data for ID=qQMjF9rAw6Q [BibisBeautyPalace]
#  - queried 100 comments (took 0.1963s) from ID=qQMjF9rAw6Q [BibisBeautyPalace]
#  - retrieving comment data for ID=2vWRjawDs_Q [BibisBeautyPalace]
#  - queried 100 comments (took 0.617s) from ID=2vWRjawDs_Q [BibisBeautyPalace]
#  - retrieving comment data for ID=TIcqQXqNGpk [BibisBeautyPalace]
#  - queried 100 comments (took 0.4172s) from ID=TIcqQXqNGpk [BibisBeautyPalace]
#  - retrieving comment data for ID=TqhW16_9Yp8 [BibisBeautyPalace]
#  - queried 100 comments (took 0.2017s) from ID=TqhW16_9Yp8 [BibisBeautyPalace]
#  - retrieving comment data for ID=jBIWKu3CRAs [BibisBeautyPalace]
#  - queried 100 comments (took 0.2159s) from ID=jBIWKu3CRAs [BibisBeautyPalace]
#  - retrieving comment data for ID=QHeZ4QmDsQg [BibisBeautyPalace]
#  - queried 100 comments (took 0.1985s) from ID=QHeZ4QmDsQg [BibisBeautyPalace]
#  - retrieving comment data for ID=e_6moTIANqg [BibisBeautyPalace]
#  - queried 100 comments (took 0.3849s) from ID=e_6moTIANqg [BibisBeautyPalace]
#  - retrieving comment data for ID=k8Q-0ApnHcI [BibisBeautyPalace]
#  - queried 100 comments (took 0.4085s) from ID=k8Q-0ApnHcI [BibisBeautyPalace]
#  - retrieving comment data for ID=Sh_ouV6Ym0I [BibisBeautyPalace]
#  - queried 100 comments (took 0.216s) from ID=Sh_ouV6Ym0I [BibisBeautyPalace]
#  - retrieving comment data for ID=uHL-_PrubWw [BibisBeautyPalace]
#  - queried 100 comments (took 0.2007s) from ID=uHL-_PrubWw [BibisBeautyPalace]
#  - retrieving comment data for ID=tBVIVp7VKHo [BibisBeautyPalace]
#  - queried 100 comments (took 0.3058s) from ID=tBVIVp7VKHo [BibisBeautyPalace]
#  - saving 3000comments from creator [BibisBeautyPalace] to local harddrive
#  - ... SAVED CSV SUCCESSFULLY
# == QUERYING DATA FOR CHANNEL [ungespielt]
#  - got video data for ungespieltwith 120 videos
#  - retrieving comment data for ID=YslDe17rxHY [ungespielt]
#  - queried 21 comments (took 0.1422s) from ID=YslDe17rxHY [ungespielt]
#  - retrieving comment data for ID=ro5WWeAnI5w [ungespielt]
#  - queried 92 comments (took 0.2021s) from ID=ro5WWeAnI5w [ungespielt]
#  - retrieving comment data for ID=1PWgxgyTVMk [ungespielt]
#  - queried 99 comments (took 0.216s) from ID=1PWgxgyTVMk [ungespielt]
#  - retrieving comment data for ID=M1ytYFIDLII [ungespielt]
#  - queried 100 comments (took 0.2099s) from ID=M1ytYFIDLII [ungespielt]
#  - retrieving comment data for ID=AuMKwKjX30Y [ungespielt]
#  - queried 100 comments (took 0.2024s) from ID=AuMKwKjX30Y [ungespielt]
#  - retrieving comment data for ID=_-1dvX1dGq0 [ungespielt]
#  - queried 100 comments (took 0.2217s) from ID=_-1dvX1dGq0 [ungespielt]
#  - retrieving comment data for ID=FDtOxrP4HEc [ungespielt]
#  - queried 100 comments (took 0.199s) from ID=FDtOxrP4HEc [ungespielt]
#  - retrieving comment data for ID=P11LGwvkSWg [ungespielt]
#  - queried 51 comments (took 0.1605s) from ID=P11LGwvkSWg [ungespielt]
#  - retrieving comment data for ID=6SYlR32xmbg [ungespielt]
#  - queried 100 comments (took 0.2065s) from ID=6SYlR32xmbg [ungespielt]
#  - retrieving comment data for ID=9Xe-G9fCH1k [ungespielt]
#  - queried 100 comments (took 0.3942s) from ID=9Xe-G9fCH1k [ungespielt]
#  - retrieving comment data for ID=iXF1gt_4KFY [ungespielt]
#  - queried 95 comments (took 0.2205s) from ID=iXF1gt_4KFY [ungespielt]
#  - retrieving comment data for ID=wjIFMMWNWZk [ungespielt]
#  - queried 100 comments (took 0.2044s) from ID=wjIFMMWNWZk [ungespielt]
#  - retrieving comment data for ID=v77CGm3sT9w [ungespielt]
#  - queried 100 comments (took 0.2321s) from ID=v77CGm3sT9w [ungespielt]
#  - retrieving comment data for ID=72JhZF-RGrY [ungespielt]
#  - queried 100 comments (took 0.2052s) from ID=72JhZF-RGrY [ungespielt]
#  - retrieving comment data for ID=KrHO7PVekQk [ungespielt]
#  - queried 100 comments (took 0.1759s) from ID=KrHO7PVekQk [ungespielt]
#  - retrieving comment data for ID=umnIDeZw3wQ [ungespielt]
#  - queried 100 comments (took 0.5362s) from ID=umnIDeZw3wQ [ungespielt]
#  - retrieving comment data for ID=S5BroocyPkU [ungespielt]
#  - queried 100 comments (took 0.4821s) from ID=S5BroocyPkU [ungespielt]
#  - retrieving comment data for ID=m0QBqxYAtRo [ungespielt]
#  - queried 100 comments (took 0.209s) from ID=m0QBqxYAtRo [ungespielt]
#  - retrieving comment data for ID=a60PXgvMnY0 [ungespielt]
#  - queried 100 comments (took 0.3762s) from ID=a60PXgvMnY0 [ungespielt]
#  - retrieving comment data for ID=qTFik2KWkOw [ungespielt]
#  - queried 44 comments (took 0.15s) from ID=qTFik2KWkOw [ungespielt]
#  - retrieving comment data for ID=PxBnPDaHoSc [ungespielt]
#  - queried 78 comments (took 0.2038s) from ID=PxBnPDaHoSc [ungespielt]
#  - retrieving comment data for ID=rV0_xmzDvnQ [ungespielt]
#  - queried 100 comments (took 0.2109s) from ID=rV0_xmzDvnQ [ungespielt]
#  - retrieving comment data for ID=pzkA7Kh0TyM [ungespielt]
#  - queried 100 comments (took 0.2422s) from ID=pzkA7Kh0TyM [ungespielt]
#  - retrieving comment data for ID=DvgLjll0RJ8 [ungespielt]
#  - queried 96 comments (took 0.2169s) from ID=DvgLjll0RJ8 [ungespielt]
#  - retrieving comment data for ID=8GQImB1cQ5c [ungespielt]
#  - queried 68 comments (took 0.269s) from ID=8GQImB1cQ5c [ungespielt]
#  - retrieving comment data for ID=rAjKJKP-JrA [ungespielt]
#  - queried 50 comments (took 0.1919s) from ID=rAjKJKP-JrA [ungespielt]
#  - retrieving comment data for ID=IT2goTo2CGw [ungespielt]
#  - queried 100 comments (took 0.259s) from ID=IT2goTo2CGw [ungespielt]
#  - retrieving comment data for ID=UkPoyCw4bgY [ungespielt]
#  - queried 100 comments (took 0.3225s) from ID=UkPoyCw4bgY [ungespielt]
#  - retrieving comment data for ID=ddP6DpY4AIY [ungespielt]
#  - queried 100 comments (took 0.1944s) from ID=ddP6DpY4AIY [ungespielt]
#  - retrieving comment data for ID=VMc4htrIUQI [ungespielt]
#  - queried 100 comments (took 0.4142s) from ID=VMc4htrIUQI [ungespielt]
#  - saving 2694comments from creator [ungespielt] to local harddrive
#  - ... SAVED CSV SUCCESSFULLY
# == QUERYING DATA FOR CHANNEL [rezo]
#  - got video data for rezowith 150 videos
#  - retrieving comment data for ID=NFNpid428c0 [rezo]
#  - queried 100 comments (took 0.1805s) from ID=NFNpid428c0 [rezo]
#  - retrieving comment data for ID=HY7-7DnP0f0 [rezo]
#  - queried 100 comments (took 0.2101s) from ID=HY7-7DnP0f0 [rezo]
#  - retrieving comment data for ID=kfj7Opc0R5E [rezo]
#  - queried 100 comments (took 0.4691s) from ID=kfj7Opc0R5E [rezo]
#  - retrieving comment data for ID=hv31vOJzpps [rezo]
#  - queried 100 comments (took 0.1926s) from ID=hv31vOJzpps [rezo]
#  - retrieving comment data for ID=DxG-7cl29F8 [rezo]
#  - queried 100 comments (took 0.4233s) from ID=DxG-7cl29F8 [rezo]
#  - retrieving comment data for ID=Ae8bUrTC5pw [rezo]
#  - queried 100 comments (took 0.336s) from ID=Ae8bUrTC5pw [rezo]
#  - retrieving comment data for ID=HC1vnDqYZF8 [rezo]
#  - queried 100 comments (took 0.1807s) from ID=HC1vnDqYZF8 [rezo]
#  - retrieving comment data for ID=g_zf-QbhWbg [rezo]
#  - queried 100 comments (took 0.204s) from ID=g_zf-QbhWbg [rezo]
#  - retrieving comment data for ID=I2TKpfh1ueU [rezo]
#  - queried 100 comments (took 0.1834s) from ID=I2TKpfh1ueU [rezo]
#  - retrieving comment data for ID=-fP090o62go [rezo]
#  - queried 100 comments (took 0.2221s) from ID=-fP090o62go [rezo]
#  - retrieving comment data for ID=CMrp9jvxxhk [rezo]
#  - queried 100 comments (took 0.2104s) from ID=CMrp9jvxxhk [rezo]
#  - retrieving comment data for ID=1HEiFpMQY2k [rezo]
#  - queried 100 comments (took 0.308s) from ID=1HEiFpMQY2k [rezo]
#  - retrieving comment data for ID=c8ZBZV-7jVg [rezo]
#  - queried 100 comments (took 0.5824s) from ID=c8ZBZV-7jVg [rezo]
#  - retrieving comment data for ID=_XQ2Px8dcXk [rezo]
#  - queried 100 comments (took 0.2153s) from ID=_XQ2Px8dcXk [rezo]
#  - retrieving comment data for ID=1BOQSQY9PPk [rezo]
#  - queried 100 comments (took 0.1959s) from ID=1BOQSQY9PPk [rezo]
#  - retrieving comment data for ID=X64Ou0Br4rI [rezo]
#  - queried 99 comments (took 0.473s) from ID=X64Ou0Br4rI [rezo]
#  - retrieving comment data for ID=qn3ar_frm10 [rezo]
#  - queried 100 comments (took 0.4304s) from ID=qn3ar_frm10 [rezo]
#  - retrieving comment data for ID=CSHJXBQinC8 [rezo]
#  - queried 100 comments (took 0.2334s) from ID=CSHJXBQinC8 [rezo]
#  - retrieving comment data for ID=ked9tdGpk0o [rezo]
#  - queried 100 comments (took 0.4167s) from ID=ked9tdGpk0o [rezo]
#  - retrieving comment data for ID=EWYshWAr434 [rezo]
#  - queried 100 comments (took 0.4251s) from ID=EWYshWAr434 [rezo]
#  - retrieving comment data for ID=QPhLTMfzRt0 [rezo]
#  - queried 100 comments (took 0.2118s) from ID=QPhLTMfzRt0 [rezo]
#  - retrieving comment data for ID=Lj9ChCefQRo [rezo]
#  - queried 100 comments (took 0.1963s) from ID=Lj9ChCefQRo [rezo]
#  - retrieving comment data for ID=Jo-dWriiDAY [rezo]
#  - queried 100 comments (took 0.1977s) from ID=Jo-dWriiDAY [rezo]
#  - retrieving comment data for ID=RLcoY1KfgnA [rezo]
#  - queried 100 comments (took 0.3804s) from ID=RLcoY1KfgnA [rezo]
#  - retrieving comment data for ID=GT91MhM36U8 [rezo]
#  - queried 100 comments (took 0.4695s) from ID=GT91MhM36U8 [rezo]
#  - retrieving comment data for ID=CgtkYopc6pk [rezo]
#  - queried 100 comments (took 0.2259s) from ID=CgtkYopc6pk [rezo]
#  - retrieving comment data for ID=6TGhfHn07BE [rezo]
#  - queried 100 comments (took 0.2059s) from ID=6TGhfHn07BE [rezo]
#  - retrieving comment data for ID=RsugYH40IVI [rezo]
#  - queried 100 comments (took 0.569s) from ID=RsugYH40IVI [rezo]
#  - retrieving comment data for ID=ZRQnCDuRa2Q [rezo]
#  - queried 100 comments (took 0.55s) from ID=ZRQnCDuRa2Q [rezo]
#  - retrieving comment data for ID=Cjy_nEo7WC4 [rezo]
#  - queried 100 comments (took 0.4625s) from ID=Cjy_nEo7WC4 [rezo]
#  - saving 2999comments from creator [rezo] to local harddrive
#  - ... SAVED CSV SUCCESSFULLY
# == QUERYING DATA FOR CHANNEL [MontanaBlack]
#  - got video data for MontanaBlackwith 180 videos
#  - retrieving comment data for ID=acd1-SbVLFg [MontanaBlack]
#  - queried 100 comments (took 0.2431s) from ID=acd1-SbVLFg [MontanaBlack]
#  - retrieving comment data for ID=Dp5kjlftU-8 [MontanaBlack]
#  - queried 100 comments (took 0.2059s) from ID=Dp5kjlftU-8 [MontanaBlack]
#  - retrieving comment data for ID=3DTytIHY5iE [MontanaBlack]
#  - queried 100 comments (took 0.2023s) from ID=3DTytIHY5iE [MontanaBlack]
#  - retrieving comment data for ID=I2zT_TJfm_s [MontanaBlack]
#  - queried 100 comments (took 1.4571s) from ID=I2zT_TJfm_s [MontanaBlack]
#  - retrieving comment data for ID=PJJDFV2qI-c [MontanaBlack]
#  - queried 100 comments (took 0.1891s) from ID=PJJDFV2qI-c [MontanaBlack]
#  - retrieving comment data for ID=fJw0_5U1U5o [MontanaBlack]
#  - queried 100 comments (took 0.3971s) from ID=fJw0_5U1U5o [MontanaBlack]
#  - retrieving comment data for ID=D96Rmy3G9jQ [MontanaBlack]
#  - queried 100 comments (took 0.1854s) from ID=D96Rmy3G9jQ [MontanaBlack]
#  - retrieving comment data for ID=hN3aT14AVJ8 [MontanaBlack]
#  - queried 100 comments (took 0.2008s) from ID=hN3aT14AVJ8 [MontanaBlack]
#  - retrieving comment data for ID=4eAdZrszqgo [MontanaBlack]
#  - queried 100 comments (took 0.2186s) from ID=4eAdZrszqgo [MontanaBlack]
#  - retrieving comment data for ID=INMb3Mst9IM [MontanaBlack]
#  - queried 100 comments (took 0.2084s) from ID=INMb3Mst9IM [MontanaBlack]
#  - retrieving comment data for ID=mO0Le91I35s [MontanaBlack]
#  - queried 100 comments (took 0.4285s) from ID=mO0Le91I35s [MontanaBlack]
#  - retrieving comment data for ID=B5ykpQ12s8o [MontanaBlack]
#  - queried 100 comments (took 0.4537s) from ID=B5ykpQ12s8o [MontanaBlack]
#  - retrieving comment data for ID=A1cycziNqJ8 [MontanaBlack]
#  - queried 100 comments (took 0.1705s) from ID=A1cycziNqJ8 [MontanaBlack]
#  - retrieving comment data for ID=b9kdh776pfQ [MontanaBlack]
#  - queried 100 comments (took 0.1988s) from ID=b9kdh776pfQ [MontanaBlack]
#  - retrieving comment data for ID=g9OMaQ8mqZs [MontanaBlack]
#  - queried 100 comments (took 0.2815s) from ID=g9OMaQ8mqZs [MontanaBlack]
#  - retrieving comment data for ID=XKJ-HCfI8_w [MontanaBlack]
#  - queried 100 comments (took 0.4137s) from ID=XKJ-HCfI8_w [MontanaBlack]
#  - retrieving comment data for ID=sx1NlHcx7VI [MontanaBlack]
#  - queried 100 comments (took 0.4271s) from ID=sx1NlHcx7VI [MontanaBlack]
#  - retrieving comment data for ID=6wQK5tVKVTk [MontanaBlack]
#  - queried 100 comments (took 0.4159s) from ID=6wQK5tVKVTk [MontanaBlack]
#  - retrieving comment data for ID=8WFi28xukUU [MontanaBlack]
#  - queried 100 comments (took 0.2965s) from ID=8WFi28xukUU [MontanaBlack]
#  - retrieving comment data for ID=GCSH4PTBNqg [MontanaBlack]
#  - queried 100 comments (took 0.4168s) from ID=GCSH4PTBNqg [MontanaBlack]
#  - retrieving comment data for ID=8YLEGITeVzQ [MontanaBlack]
#  - queried 100 comments (took 0.214s) from ID=8YLEGITeVzQ [MontanaBlack]
#  - retrieving comment data for ID=Vz9ZGt9spW8 [MontanaBlack]
#  - queried 100 comments (took 0.2036s) from ID=Vz9ZGt9spW8 [MontanaBlack]
#  - retrieving comment data for ID=V_xosonFuPk [MontanaBlack]
#  - queried 100 comments (took 0.2067s) from ID=V_xosonFuPk [MontanaBlack]
#  - retrieving comment data for ID=SXJ4KumzlgA [MontanaBlack]
#  - queried 100 comments (took 0.4387s) from ID=SXJ4KumzlgA [MontanaBlack]
#  - retrieving comment data for ID=_3CsCIOsD_k [MontanaBlack]
#  - queried 100 comments (took 0.5946s) from ID=_3CsCIOsD_k [MontanaBlack]
#  - retrieving comment data for ID=kSD1yH673Xk [MontanaBlack]
#  - queried 100 comments (took 0.4072s) from ID=kSD1yH673Xk [MontanaBlack]
#  - retrieving comment data for ID=Z2m2SMdEmzY [MontanaBlack]
# Could not get comments for video Z2m2SMdEmzY
# got no comments
#  - queried 0 comments (took 0.0871s) from ID=Z2m2SMdEmzY [MontanaBlack]
#  - retrieving comment data for ID=VUETRv2yCaI [MontanaBlack]
#  - queried 100 comments (took 0.2196s) from ID=VUETRv2yCaI [MontanaBlack]
#  - retrieving comment data for ID=w9QCREXxb6M [MontanaBlack]
#  - queried 100 comments (took 0.3971s) from ID=w9QCREXxb6M [MontanaBlack]
#  - retrieving comment data for ID=7_e4_B2tYYE [MontanaBlack]
#  - queried 100 comments (took 0.1873s) from ID=7_e4_B2tYYE [MontanaBlack]
#  - saving 2900comments from creator [MontanaBlack] to local harddrive
#  - ... SAVED CSV SUCCESSFULLY
# == QUERYING DATA FOR CHANNEL [xLL by Lisa & Lena]
#  - got video data for xLL by Lisa & Lenawith 210 videos
#  - retrieving comment data for ID=fwvJAt0qdmw [xLL by Lisa & Lena]
#  - queried 100 comments (took 1.5049s) from ID=fwvJAt0qdmw [xLL by Lisa & Lena]
#  - retrieving comment data for ID=hVu5lTHzlek [xLL by Lisa & Lena]
#  - queried 100 comments (took 0.384s) from ID=hVu5lTHzlek [xLL by Lisa & Lena]
#  - retrieving comment data for ID=WWpVolMoCQE [xLL by Lisa & Lena]
#  - queried 100 comments (took 0.3086s) from ID=WWpVolMoCQE [xLL by Lisa & Lena]
#  - retrieving comment data for ID=eCsfSADB6PA [xLL by Lisa & Lena]
#  - queried 100 comments (took 0.4083s) from ID=eCsfSADB6PA [xLL by Lisa & Lena]
#  - retrieving comment data for ID=vhouRh2PLPA [xLL by Lisa & Lena]
#  - queried 100 comments (took 0.3896s) from ID=vhouRh2PLPA [xLL by Lisa & Lena]
#  - retrieving comment data for ID=yDTe1TVG5v0 [xLL by Lisa & Lena]
#  - queried 100 comments (took 0.3954s) from ID=yDTe1TVG5v0 [xLL by Lisa & Lena]
#  - retrieving comment data for ID=RyJfGzZW8hg [xLL by Lisa & Lena]
#  - queried 100 comments (took 0.1845s) from ID=RyJfGzZW8hg [xLL by Lisa & Lena]
#  - retrieving comment data for ID=TZ2hIXV-m4o [xLL by Lisa & Lena]
#  - queried 100 comments (took 0.2075s) from ID=TZ2hIXV-m4o [xLL by Lisa & Lena]
#  - retrieving comment data for ID=wuh-aDPzAas [xLL by Lisa & Lena]
#  - queried 100 comments (took 0.1927s) from ID=wuh-aDPzAas [xLL by Lisa & Lena]
#  - retrieving comment data for ID=_z5MKV-qmEQ [xLL by Lisa & Lena]
#  - queried 100 comments (took 0.1809s) from ID=_z5MKV-qmEQ [xLL by Lisa & Lena]
#  - retrieving comment data for ID=Ia2lTC0dgyY [xLL by Lisa & Lena]
#  - queried 100 comments (took 0.4336s) from ID=Ia2lTC0dgyY [xLL by Lisa & Lena]
#  - retrieving comment data for ID=qfvtep28ko4 [xLL by Lisa & Lena]
#  - queried 20 comments (took 0.3042s) from ID=qfvtep28ko4 [xLL by Lisa & Lena]
#  - retrieving comment data for ID=LUJeN1CjH9s [xLL by Lisa & Lena]
# Could not get comments for video LUJeN1CjH9s
# got no comments
#  - queried 0 comments (took 0.0516s) from ID=LUJeN1CjH9s [xLL by Lisa & Lena]
#  - retrieving comment data for ID=rdWkXGArdjA [xLL by Lisa & Lena]
# Could not get comments for video rdWkXGArdjA
# got no comments
#  - queried 0 comments (took 0.0837s) from ID=rdWkXGArdjA [xLL by Lisa & Lena]
#  - retrieving comment data for ID=RV29eBiaVhc [xLL by Lisa & Lena]
# Could not get comments for video RV29eBiaVhc
# got no comments
#  - queried 0 comments (took 0.0833s) from ID=RV29eBiaVhc [xLL by Lisa & Lena]
#  - retrieving comment data for ID=dqr6eic6PBg [xLL by Lisa & Lena]
# Could not get comments for video dqr6eic6PBg
# got no comments
#  - queried 0 comments (took 0.0819s) from ID=dqr6eic6PBg [xLL by Lisa & Lena]
#  - retrieving comment data for ID=hAEth8ZwMKE [xLL by Lisa & Lena]
# Could not get comments for video hAEth8ZwMKE
# got no comments
#  - queried 0 comments (took 0.1496s) from ID=hAEth8ZwMKE [xLL by Lisa & Lena]
#  - retrieving comment data for ID=WOTARgOfTZ0 [xLL by Lisa & Lena]
# Could not get comments for video WOTARgOfTZ0
# got no comments
#  - queried 0 comments (took 0.0821s) from ID=WOTARgOfTZ0 [xLL by Lisa & Lena]
#  - retrieving comment data for ID=UKOmNgJylvA [xLL by Lisa & Lena]
# Could not get comments for video UKOmNgJylvA
# got no comments
#  - queried 0 comments (took 0.1486s) from ID=UKOmNgJylvA [xLL by Lisa & Lena]
#  - retrieving comment data for ID=L12I5xySoHU [xLL by Lisa & Lena]
# Could not get comments for video L12I5xySoHU
# got no comments
#  - queried 0 comments (took 0.0848s) from ID=L12I5xySoHU [xLL by Lisa & Lena]
#  - retrieving comment data for ID=uR2RhUg-zZM [xLL by Lisa & Lena]
# Could not get comments for video uR2RhUg-zZM
# got no comments
#  - queried 0 comments (took 0.085s) from ID=uR2RhUg-zZM [xLL by Lisa & Lena]
#  - retrieving comment data for ID=BFlkLss3Y94 [xLL by Lisa & Lena]
# Could not get comments for video BFlkLss3Y94
# got no comments
#  - queried 0 comments (took 0.082s) from ID=BFlkLss3Y94 [xLL by Lisa & Lena]
#  - retrieving comment data for ID=3dr0VLWdadM [xLL by Lisa & Lena]
# Could not get comments for video 3dr0VLWdadM
# got no comments
#  - queried 0 comments (took 0.087s) from ID=3dr0VLWdadM [xLL by Lisa & Lena]
#  - retrieving comment data for ID=dilHrCtO670 [xLL by Lisa & Lena]
# Could not get comments for video dilHrCtO670
# got no comments
#  - queried 0 comments (took 0.0977s) from ID=dilHrCtO670 [xLL by Lisa & Lena]
#  - retrieving comment data for ID=eXKCngbGv2c [xLL by Lisa & Lena]
# Could not get comments for video eXKCngbGv2c
# got no comments
#  - queried 0 comments (took 0.0835s) from ID=eXKCngbGv2c [xLL by Lisa & Lena]
#  - retrieving comment data for ID=LlLJvls5ves [xLL by Lisa & Lena]
# Could not get comments for video LlLJvls5ves
# got no comments
#  - queried 0 comments (took 0.0963s) from ID=LlLJvls5ves [xLL by Lisa & Lena]
#  - retrieving comment data for ID=BuA9Siwwk8c [xLL by Lisa & Lena]
# Could not get comments for video BuA9Siwwk8c
# got no comments
#  - queried 0 comments (took 0.1459s) from ID=BuA9Siwwk8c [xLL by Lisa & Lena]
#  - retrieving comment data for ID=lj_htsgNDo0 [xLL by Lisa & Lena]
# Could not get comments for video lj_htsgNDo0
# got no comments
#  - queried 0 comments (took 0.0584s) from ID=lj_htsgNDo0 [xLL by Lisa & Lena]
#  - retrieving comment data for ID=tCxk_R--BWM [xLL by Lisa & Lena]
# Could not get comments for video tCxk_R--BWM
# got no comments
#  - queried 0 comments (took 0.0838s) from ID=tCxk_R--BWM [xLL by Lisa & Lena]
#  - retrieving comment data for ID=pybdebFWyMY [xLL by Lisa & Lena]
# Could not get comments for video pybdebFWyMY
# got no comments
#  - queried 0 comments (took 0.0869s) from ID=pybdebFWyMY [xLL by Lisa & Lena]
#  - saving 1120comments from creator [xLL by Lisa & Lena] to local harddrive
#  - ... SAVED CSV SUCCESSFULLY
# == QUERYING DATA FOR CHANNEL [Gronkh]
#  - got video data for Gronkhwith 240 videos
#  - retrieving comment data for ID=2pjuqi4imEU [Gronkh]
#  - queried 21 comments (took 0.1566s) from ID=2pjuqi4imEU [Gronkh]
#  - retrieving comment data for ID=UJ0ZCllwqm0 [Gronkh]
#  - queried 30 comments (took 0.1898s) from ID=UJ0ZCllwqm0 [Gronkh]
#  - retrieving comment data for ID=lLoQElzUeLk [Gronkh]
#  - queried 33 comments (took 0.3034s) from ID=lLoQElzUeLk [Gronkh]
#  - retrieving comment data for ID=MY2HESnK86Y [Gronkh]
#  - queried 51 comments (took 0.2026s) from ID=MY2HESnK86Y [Gronkh]
#  - retrieving comment data for ID=iUsUknqDneQ [Gronkh]
#  - queried 99 comments (took 0.2232s) from ID=iUsUknqDneQ [Gronkh]
#  - retrieving comment data for ID=HJGogQkpuyo [Gronkh]
#  - queried 52 comments (took 0.1481s) from ID=HJGogQkpuyo [Gronkh]
#  - retrieving comment data for ID=kXhzk6v0654 [Gronkh]
#  - queried 63 comments (took 0.1743s) from ID=kXhzk6v0654 [Gronkh]
#  - retrieving comment data for ID=o8O5Pc9qYAA [Gronkh]
#  - queried 100 comments (took 0.1841s) from ID=o8O5Pc9qYAA [Gronkh]
#  - retrieving comment data for ID=B3_NyMnQMOE [Gronkh]
#  - queried 62 comments (took 0.3424s) from ID=B3_NyMnQMOE [Gronkh]
#  - retrieving comment data for ID=Az7A31E4VOI [Gronkh]
#  - queried 80 comments (took 0.1858s) from ID=Az7A31E4VOI [Gronkh]
#  - retrieving comment data for ID=E2qadbV-kas [Gronkh]
#  - queried 77 comments (took 0.187s) from ID=E2qadbV-kas [Gronkh]
#  - retrieving comment data for ID=X0Klf7Rt6WA [Gronkh]
#  - queried 100 comments (took 0.1943s) from ID=X0Klf7Rt6WA [Gronkh]
#  - retrieving comment data for ID=iDTBJX3HtyA [Gronkh]
#  - queried 100 comments (took 0.1951s) from ID=iDTBJX3HtyA [Gronkh]
#  - retrieving comment data for ID=HP8d98V8Qt8 [Gronkh]
#  - queried 100 comments (took 0.2056s) from ID=HP8d98V8Qt8 [Gronkh]
#  - retrieving comment data for ID=NLHxOe6wFB4 [Gronkh]
#  - queried 100 comments (took 0.2055s) from ID=NLHxOe6wFB4 [Gronkh]
#  - retrieving comment data for ID=IGbQ3tGgq90 [Gronkh]
#  - queried 80 comments (took 0.4833s) from ID=IGbQ3tGgq90 [Gronkh]
#  - retrieving comment data for ID=yucxpx-_wT8 [Gronkh]
#  - queried 100 comments (took 0.2205s) from ID=yucxpx-_wT8 [Gronkh]
#  - retrieving comment data for ID=fUm79527zIU [Gronkh]
#  - queried 100 comments (took 0.2169s) from ID=fUm79527zIU [Gronkh]
#  - retrieving comment data for ID=Ltiy0AKiDRc [Gronkh]
#  - queried 89 comments (took 0.1896s) from ID=Ltiy0AKiDRc [Gronkh]
#  - retrieving comment data for ID=Lk2NBbwAt90 [Gronkh]
#  - queried 79 comments (took 0.1872s) from ID=Lk2NBbwAt90 [Gronkh]
#  - retrieving comment data for ID=yVw72fcuKWA [Gronkh]
#  - queried 100 comments (took 0.193s) from ID=yVw72fcuKWA [Gronkh]
#  - retrieving comment data for ID=Xp0vNPFUAp8 [Gronkh]
#  - queried 100 comments (took 0.2131s) from ID=Xp0vNPFUAp8 [Gronkh]
#  - retrieving comment data for ID=8bEqLwb3Crw [Gronkh]
#  - queried 100 comments (took 0.1996s) from ID=8bEqLwb3Crw [Gronkh]
#  - retrieving comment data for ID=jSM1z4mbs3k [Gronkh]
#  - queried 100 comments (took 1.4514s) from ID=jSM1z4mbs3k [Gronkh]
#  - retrieving comment data for ID=_ZSxX1XNcO0 [Gronkh]
#  - queried 99 comments (took 0.2044s) from ID=_ZSxX1XNcO0 [Gronkh]
#  - retrieving comment data for ID=h1fcEq5UawQ [Gronkh]
#  - queried 88 comments (took 0.1895s) from ID=h1fcEq5UawQ [Gronkh]
#  - retrieving comment data for ID=qsOCgZ45sdU [Gronkh]
#  - queried 99 comments (took 0.4559s) from ID=qsOCgZ45sdU [Gronkh]
#  - retrieving comment data for ID=I7bloerv2h8 [Gronkh]
#  - queried 84 comments (took 0.6451s) from ID=I7bloerv2h8 [Gronkh]
#  - retrieving comment data for ID=Z92fsUpGMz8 [Gronkh]
#  - queried 100 comments (took 0.1907s) from ID=Z92fsUpGMz8 [Gronkh]
#  - retrieving comment data for ID=V6PkMenXg9Q [Gronkh]
#  - queried 88 comments (took 0.2216s) from ID=V6PkMenXg9Q [Gronkh]
#  - saving 2474comments from creator [Gronkh] to local harddrive
#  - ... SAVED CSV SUCCESSFULLY
# == QUERYING DATA FOR CHANNEL [Pamela Reif]
#  - got video data for Pamela Reifwith 270 videos
#  - retrieving comment data for ID=HLQ0NCN_Z4Q [Pamela Reif]
#  - queried 99 comments (took 0.2267s) from ID=HLQ0NCN_Z4Q [Pamela Reif]
#  - retrieving comment data for ID=jPSORpgautA [Pamela Reif]
#  - queried 100 comments (took 0.2145s) from ID=jPSORpgautA [Pamela Reif]
#  - retrieving comment data for ID=TUx-tEg2Xac [Pamela Reif]
#  - queried 100 comments (took 0.3669s) from ID=TUx-tEg2Xac [Pamela Reif]
#  - retrieving comment data for ID=rNWBdTgTj0Q [Pamela Reif]
#  - queried 100 comments (took 0.2739s) from ID=rNWBdTgTj0Q [Pamela Reif]
#  - retrieving comment data for ID=KmVDECXCb1Q [Pamela Reif]
#  - queried 100 comments (took 0.1968s) from ID=KmVDECXCb1Q [Pamela Reif]
#  - retrieving comment data for ID=l4IKrZymsXU [Pamela Reif]
# Could not get comments for video l4IKrZymsXU
# got no comments
#  - queried 0 comments (took 0.1554s) from ID=l4IKrZymsXU [Pamela Reif]
#  - retrieving comment data for ID=6-KnVQMGjZ8 [Pamela Reif]
#  - queried 100 comments (took 0.2009s) from ID=6-KnVQMGjZ8 [Pamela Reif]
#  - retrieving comment data for ID=bxUgB2kKu94 [Pamela Reif]
#  - queried 100 comments (took 0.2058s) from ID=bxUgB2kKu94 [Pamela Reif]
#  - retrieving comment data for ID=btivGZ_l8tA [Pamela Reif]
#  - queried 100 comments (took 0.198s) from ID=btivGZ_l8tA [Pamela Reif]
#  - retrieving comment data for ID=DISC6FiaM4E [Pamela Reif]
#  - queried 100 comments (took 0.399s) from ID=DISC6FiaM4E [Pamela Reif]
#  - retrieving comment data for ID=HftkZL89FRM [Pamela Reif]
#  - queried 100 comments (took 0.1923s) from ID=HftkZL89FRM [Pamela Reif]
#  - retrieving comment data for ID=0P69MCqTYj4 [Pamela Reif]
#  - queried 100 comments (took 0.2588s) from ID=0P69MCqTYj4 [Pamela Reif]
#  - retrieving comment data for ID=MgwaKDSevcs [Pamela Reif]
#  - queried 100 comments (took 0.1847s) from ID=MgwaKDSevcs [Pamela Reif]
#  - retrieving comment data for ID=enK76XbR9Q0 [Pamela Reif]
#  - queried 100 comments (took 0.287s) from ID=enK76XbR9Q0 [Pamela Reif]
#  - retrieving comment data for ID=Gg3W2x0dnDg [Pamela Reif]
#  - queried 100 comments (took 0.1931s) from ID=Gg3W2x0dnDg [Pamela Reif]
#  - retrieving comment data for ID=aSVqGWfNbns [Pamela Reif]
#  - queried 100 comments (took 0.2202s) from ID=aSVqGWfNbns [Pamela Reif]
#  - retrieving comment data for ID=Wdq_pRXwg_8 [Pamela Reif]
#  - queried 100 comments (took 0.4259s) from ID=Wdq_pRXwg_8 [Pamela Reif]
#  - retrieving comment data for ID=btCBYtUPEVU [Pamela Reif]
#  - queried 100 comments (took 0.2101s) from ID=btCBYtUPEVU [Pamela Reif]
#  - retrieving comment data for ID=3LiZGIIXyFc [Pamela Reif]
#  - queried 100 comments (took 0.2268s) from ID=3LiZGIIXyFc [Pamela Reif]
#  - retrieving comment data for ID=Yw9BKk83Gng [Pamela Reif]
#  - queried 100 comments (took 0.2124s) from ID=Yw9BKk83Gng [Pamela Reif]
#  - retrieving comment data for ID=FAkZLhi30Xw [Pamela Reif]
#  - queried 100 comments (took 0.3867s) from ID=FAkZLhi30Xw [Pamela Reif]
#  - retrieving comment data for ID=5rsLU-J8aPM [Pamela Reif]
#  - queried 100 comments (took 0.1849s) from ID=5rsLU-J8aPM [Pamela Reif]
#  - retrieving comment data for ID=eH5Ng_9bsUQ [Pamela Reif]
#  - queried 100 comments (took 0.3985s) from ID=eH5Ng_9bsUQ [Pamela Reif]
#  - retrieving comment data for ID=_hwvmGZuBeY [Pamela Reif]
#  - queried 100 comments (took 0.4539s) from ID=_hwvmGZuBeY [Pamela Reif]
#  - retrieving comment data for ID=NCfOoyhTwQw [Pamela Reif]
#  - queried 100 comments (took 0.2255s) from ID=NCfOoyhTwQw [Pamela Reif]
#  - retrieving comment data for ID=LcxzO9FSLfQ [Pamela Reif]
#  - queried 100 comments (took 0.2161s) from ID=LcxzO9FSLfQ [Pamela Reif]
#  - retrieving comment data for ID=Y1jNEca245I [Pamela Reif]
#  - queried 100 comments (took 0.4343s) from ID=Y1jNEca245I [Pamela Reif]
#  - retrieving comment data for ID=YLHfarYD4IU [Pamela Reif]
#  - queried 100 comments (took 0.1964s) from ID=YLHfarYD4IU [Pamela Reif]
#  - retrieving comment data for ID=4asZsVNS7OM [Pamela Reif]
#  - queried 100 comments (took 0.2196s) from ID=4asZsVNS7OM [Pamela Reif]
#  - retrieving comment data for ID=ZXZTDH93A6c [Pamela Reif]
#  - queried 100 comments (took 0.1865s) from ID=ZXZTDH93A6c [Pamela Reif]
#  - saving 2899comments from creator [Pamela Reif] to local harddrive
#  - ... SAVED CSV SUCCESSFULLY
# == QUERYING DATA FOR CHANNEL [Julien Bam]
#  - got video data for Julien Bamwith 300 videos
#  - retrieving comment data for ID=iOd_IXAcyYE [Julien Bam]
#  - queried 100 comments (took 0.2957s) from ID=iOd_IXAcyYE [Julien Bam]
#  - retrieving comment data for ID=rKidiBm4JGk [Julien Bam]
#  - queried 100 comments (took 0.2423s) from ID=rKidiBm4JGk [Julien Bam]
#  - retrieving comment data for ID=IfBhRM-4vHU [Julien Bam]
#  - queried 100 comments (took 0.2324s) from ID=IfBhRM-4vHU [Julien Bam]
#  - retrieving comment data for ID=kxHfPFnMVaA [Julien Bam]
#  - queried 100 comments (took 0.3984s) from ID=kxHfPFnMVaA [Julien Bam]
#  - retrieving comment data for ID=aKJl0Rnqqpg [Julien Bam]
#  - queried 100 comments (took 0.3996s) from ID=aKJl0Rnqqpg [Julien Bam]
#  - retrieving comment data for ID=H1p9k2rj-8U [Julien Bam]
#  - queried 100 comments (took 0.2165s) from ID=H1p9k2rj-8U [Julien Bam]
#  - retrieving comment data for ID=hSREEzhCB6k [Julien Bam]
#  - queried 100 comments (took 0.2304s) from ID=hSREEzhCB6k [Julien Bam]
#  - retrieving comment data for ID=Rjg9YGuKCuw [Julien Bam]
#  - queried 100 comments (took 0.1797s) from ID=Rjg9YGuKCuw [Julien Bam]
#  - retrieving comment data for ID=9ygh5pKT9ZU [Julien Bam]
#  - queried 100 comments (took 0.2093s) from ID=9ygh5pKT9ZU [Julien Bam]
#  - retrieving comment data for ID=SN3z7e7Mjio [Julien Bam]
#  - queried 100 comments (took 0.4724s) from ID=SN3z7e7Mjio [Julien Bam]
#  - retrieving comment data for ID=ZkGC8HQvPz8 [Julien Bam]
#  - queried 100 comments (took 0.1949s) from ID=ZkGC8HQvPz8 [Julien Bam]
#  - retrieving comment data for ID=80xv6xbUKyA [Julien Bam]
#  - queried 100 comments (took 0.2107s) from ID=80xv6xbUKyA [Julien Bam]
#  - retrieving comment data for ID=vn5noYJgJgo [Julien Bam]
#  - queried 100 comments (took 0.3034s) from ID=vn5noYJgJgo [Julien Bam]
#  - retrieving comment data for ID=i272lr6sk2I [Julien Bam]
#  - queried 100 comments (took 0.2777s) from ID=i272lr6sk2I [Julien Bam]
#  - retrieving comment data for ID=K6BbVjo-UC8 [Julien Bam]
#  - queried 100 comments (took 0.4129s) from ID=K6BbVjo-UC8 [Julien Bam]
#  - retrieving comment data for ID=3aMoo8ho0VY [Julien Bam]
#  - queried 100 comments (took 0.2329s) from ID=3aMoo8ho0VY [Julien Bam]
#  - retrieving comment data for ID=LA1xSmpwYDE [Julien Bam]
#  - queried 100 comments (took 0.3734s) from ID=LA1xSmpwYDE [Julien Bam]
#  - retrieving comment data for ID=YcP5MEnPGyM [Julien Bam]
#  - queried 100 comments (took 0.2009s) from ID=YcP5MEnPGyM [Julien Bam]
#  - retrieving comment data for ID=07VfwFwqNks [Julien Bam]
#  - queried 100 comments (took 0.4135s) from ID=07VfwFwqNks [Julien Bam]
#  - retrieving comment data for ID=LLFesC65hfQ [Julien Bam]
#  - queried 100 comments (took 0.2679s) from ID=LLFesC65hfQ [Julien Bam]
#  - retrieving comment data for ID=5KmzQ9ztvos [Julien Bam]
#  - queried 100 comments (took 1.122s) from ID=5KmzQ9ztvos [Julien Bam]
#  - retrieving comment data for ID=xXHxd6JebbY [Julien Bam]
#  - queried 100 comments (took 0.3444s) from ID=xXHxd6JebbY [Julien Bam]
#  - retrieving comment data for ID=LRaENLSfLIY [Julien Bam]
#  - queried 100 comments (took 0.2197s) from ID=LRaENLSfLIY [Julien Bam]
#  - retrieving comment data for ID=3U3RA-buzVo [Julien Bam]
#  - queried 100 comments (took 0.1908s) from ID=3U3RA-buzVo [Julien Bam]
#  - retrieving comment data for ID=2JOQSd1MB90 [Julien Bam]
#  - queried 100 comments (took 0.2367s) from ID=2JOQSd1MB90 [Julien Bam]
#  - retrieving comment data for ID=FIwwXnMio24 [Julien Bam]
#  - queried 100 comments (took 0.2246s) from ID=FIwwXnMio24 [Julien Bam]
#  - retrieving comment data for ID=v1mDeIkWR7c [Julien Bam]
#  - queried 100 comments (took 0.5203s) from ID=v1mDeIkWR7c [Julien Bam]
#  - retrieving comment data for ID=AxS87IgCvBM [Julien Bam]
#  - queried 100 comments (took 0.2023s) from ID=AxS87IgCvBM [Julien Bam]
#  - retrieving comment data for ID=qHb8f_mFNIk [Julien Bam]
#  - queried 100 comments (took 0.2886s) from ID=qHb8f_mFNIk [Julien Bam]
#  - retrieving comment data for ID=FBmXmL-wNM0 [Julien Bam]
#  - queried 100 comments (took 0.1961s) from ID=FBmXmL-wNM0 [Julien Bam]
#  - saving 3000comments from creator [Julien Bam] to local harddrive
#  - ... SAVED CSV SUCCESSFULLY

# %%
csv_data.to_csv('C:/Users/D074066/Downloads/emojitest.csv', sep=';',encoding='utf-32')

# %%
video_data = video_df[0:0]


commentdata_per_channel = {}

# iterate over all channels
for channel_title in video_df['channelTitle'].unique():
    # get videos for selected channel
    temp = video_df.loc[video_df['channelTitle']==channel_title]
    # sort data by video view count
    temp.sort_values('viewCount', ascending=False)
    # only get top 30 videos
    temp = temp.head(30)
    temp.reset_index(inplace=True)
    temp.apply(pd.to_numeric, errors = 'coerce', axis = 1)
    # temp.drop(temp.columns[[0]], axis=1, inplace=True)

    # append found videos to video_data dataframe
    video_data = pd.concat([temp,video_data],  ignore_index=False)
    # video_data.append(temp)


    # get all comments for each video
    if False:
        # get comments for selected video by video id
        comments = get_comments_in_videos(youtube, video_ids=temp['video_id'].to_list())
        # store comments per youtube channel in dictionary
        commentdata_per_channel[channel_title] = comments
    else:
        comments_query = get_comment_threads(youtube=youtube, video_ids=temp['video_id'].to_list())
        comments = load_comments(result=comments_query)
        


    comments.to_csv('C:/Users/D074066/Downloads/'+channel_title+'_comments_top30.csv', sep=';')

video_data.to_csv('C:/Users/D074066/Downloads/'+'videos_top30.csv', sep=';')
# Out:
# Got 30 video IDs
# Got 30 video IDs
# Got 30 video IDs
# Could not get comments for video 1OzUV_GA_qM
# Got 30 video IDs
# Got 30 video IDs
# Could not get comments for video l4IKrZymsXU
# Got 30 video IDs
# Could not get comments for video Z2m2SMdEmzY
# Got 30 video IDs
# Could not get comments for video LUJeN1CjH9s
# Could not get comments for video rdWkXGArdjA
# Could not get comments for video RV29eBiaVhc
# Could not get comments for video dqr6eic6PBg
# Could not get comments for video hAEth8ZwMKE
# Could not get comments for video WOTARgOfTZ0
# Could not get comments for video UKOmNgJylvA
# Could not get comments for video L12I5xySoHU
# Could not get comments for video uR2RhUg-zZM
# Could not get comments for video BFlkLss3Y94
# Could not get comments for video 3dr0VLWdadM
# Could not get comments for video dilHrCtO670
# Could not get comments for video eXKCngbGv2c
# Could not get comments for video LlLJvls5ves
# Could not get comments for video BuA9Siwwk8c
# Could not get comments for video lj_htsgNDo0
# Could not get comments for video tCxk_R--BWM
# Could not get comments for video pybdebFWyMY
# Got 30 video IDs
# Got 30 video IDs
# Got 30 video IDs

# %% [markdown]
# Preprocessing of comments
#
# stopwords, lowercase, no emojis etc.

# %%
#remove emojis
pip install demoji
import demoji

demoji.download_codes()

def remove_em(text):
    dem = demoji.findall(text)
    for item in dem.keys():
        text = text.replace(item, "")
    return text

# %%
#remove puncations

#library that contains punctuation
import string
string.punctuation

#defining the function to remove punctuation
def remove_punctuation(text):
    punctuationfree="".join([i for i in text if i not in string.punctuation])
    return punctuationfree
#storing the puntuation free text
data['clean_msg']= data['v2'].apply(lambda x:remove_punctuation(x))
data.head()

# %%
#lowering 
data['msg_lower']= data['clean_msg'].apply(lambda x: x.lower())

# %%
#language detection
pip install langdetect

# %%
categories_splitted = video_data['topicCategories'].apply(pd.Series)
video_data['category'] = categories_splitted.iloc[:,0].astype(str)
video_data['category'] = video_data['category'].apply(lambda cat: cat.replace('https://en.wikipedia.org/wiki/','').split('_(')[0])

# %%
video_data.to_csv('C:/Users/D074066/Downloads/'+'videos_top30_clean.csv', sep=';')

# %% [markdown]
# ### Playground

# %%
def clean_alt_list(list_):
    list_ = list_.replace(', ', '","')
    list_ = list_.replace('[', '["')
    list_ = list_.replace(']', '"]')
    return list_

video_data['category'] = video_data['topicCategories']
# video_data['category'] = video_data['category'].apply(clean_alt_list)
temp = video_data['category'].apply(pd.Series)
temp2 = temp.iloc[:,0]
# Out:
# C:\Users\D074066\AppData\Local\Temp\ipykernel_32900\229743097.py:9: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   temp = video_data['category'].apply(pd.Series)
# C:\Users\D074066\AppData\Local\Temp\ipykernel_32900\229743097.py:9: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   temp = video_data['category'].apply(pd.Series)
# C:\Users\D074066\AppData\Local\Temp\ipykernel_32900\229743097.py:9: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   temp = video_data['category'].apply(pd.Series)
# C:\Users\D074066\AppData\Local\Temp\ipykernel_32900\229743097.py:9: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   temp = video_data['category'].apply(pd.Series)
# C:\Users\D074066\AppData\Local\Temp\ipykernel_32900\229743097.py:9: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   temp = video_data['category'].apply(pd.Series)

# %%
nltk.download('punkt');

def tokenize(column):
    """Tokenizes a Pandas dataframe column and returns a list of tokens.

    Args:
        column: Pandas dataframe column (i.e. df['text']).

    Returns:
        tokens (list): Tokenized list, i.e. [Donald, Trump, tweets]

    """

    tokens = nltk.word_tokenize(column)
    return [w for w in tokens if w.isalpha()]

# %%
df['tokenized'] = df.apply(lambda x: tokenize(x['clean_punctations']), axis=1)
df

# %%
# remove stop words --> im Stemming mitdrin
#stops = set(stopwords.words('german'))
#german_stop_words = stopwords.words('german')
#df['without_stopwords'] = df['urls'].apply(lambda x: ' '.join([word for word in x.split() if word not in (german_stop_words)]))
#df

# %%
import re

SEARCHSTRING = 'https://en.wikipedia.org/wiki/Hallo_(mama)'

c = SEARCHSTRING.replace('https://en.wikipedia.org/wiki/','')
c = c.split('_(')[0]
print(c)

test = video_data.iloc[1]['topicCategories']

c = test[0]
print(c)

print(c.replace('https://en.wikipedia.org/wiki/',''))
print(c.split('_(')[0])
# Out:
# Hallo
# https://en.wikipedia.org/wiki/Lifestyle_(sociology)
# Lifestyle_(sociology)
# https://en.wikipedia.org/wiki/Lifestyle
